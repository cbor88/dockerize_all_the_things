# %%
import csv

import numpy as np
import pandas as pd

FILE = 'files/csvs/ricardo_eletro_scraped.csv.CONVERTED.csv'
SEPARATOR = '\t'

df = pd.read_csv(FILE, SEPARATOR, error_bad_lines=False)
# df = pd.read_csv(FILE, SEPARATOR, error_bad_lines=False, quoting=csv.QUOTE_NONE)

df = df.fillna(value='')

# %%
df.count()
# Out:
# _id.id               35053
# ean                  35053
# brand                35053
# name                 35053
# product_type         35053
# price                35053
# special_price        35053
# department           35053
# category             35053
# url                  35053
# available            35053
# instalments          35053
# instalment_value     35053
# image_url            35053
# variation_label      35053
# tyre.width           35053
# tyre.aspect_ratio    35053
# tyre.rim_diameter    35053
# tyre.load_index      35053
# tyre.speed_rating    35053
# dtype: int64

# %%
df.columns
# Out:
# Index([u'_id.id', u'ean', u'brand', u'name', u'product_type', u'price',
#        u'special_price', u'department', u'category', u'url', u'available',
#        u'instalments', u'instalment_value', u'image_url', u'variation_label',
#        u'tyre.width', u'tyre.aspect_ratio', u'tyre.rim_diameter',
#        u'tyre.load_index', u'tyre.speed_rating'],
#       dtype='object')

# %%
df.head(2)
# Out:
#    _id.id ean    brand                                               name  \
# 0  622933      Seculus  Relógio Feminino Guess  Analógico  Pulseira de...
# 1  375655        Epson                     Scanner de Mesa GT S55 - Epson
#
#        product_type  price  special_price                 department  \
# 0         analógico    799          309.9                   relógios
# 1  scanners de mesa   2699         2599.0  acessórios de informática
#
#               category                                                url  \
# 0     relógio feminino  http://www.ricardoeletro.com.br/Produto/Relogi...
# 1  scanners e leitores  http://www.ricardoeletro.com.br/Produto/Scanne...
#
#   available  instalments  instalment_value  \
# 0      True           10             30.99
# 1      True           10            259.90
#
#                                            image_url variation_label  \
# 0  http://images.maquinadevendas.com.br/produto/6...
# ...

# %%
df[df['available'] == True].tail(3)
# Out:
#        _id.id ean   brand                                               name  \
# 35050  445917          LG  TV LED 42' LG Full HD com Painel IPS  Converso...
# 35051  615381      Philco  Smart TV LED 42' Philco Full HD com WiFi Integ...
# 35052  625560      Philco  Smart TV LED 40' Philco Full HD com WiFi Integ...
#
#        product_type  price  special_price  department category  \
# 35050  de 39" a 43"   1799         1549.9  tv e vídeo       tv
# 35051  de 39" a 43"   1899         1459.9  tv e vídeo       tv
# 35052  de 39" a 43"   1799         1399.9  tv e vídeo       tv
#
#                                                      url available  \
# 35050  http://www.ricardoeletro.com.br/Produto/TV-LED...      True
# 35051  http://www.ricardoeletro.com.br/Produto/Smart-...      True
# 35052  http://www.ricardoeletro.com.br/Produto/Smart-...      True
#
#        instalments  instalment_value  \
# 35050           10            154.99
# 35051           10            145.99
# ...

# %%
df[df['available'] == False].head(3)
# Out:
#      _id.id ean       brand  \
# 33   402481      Electrolux
# 59  C300870          Castor
# 68  C504167          Consul
#
#                                                  name  \
# 33  Micro-ondas Electrolux 31 Litros Inox Grill Bl...
# 59  Cama Box Casal + Colchão Ecolchao Platinum Mol...
# 68  Ar Condicionado Split Consul 12.000 BTUs Frio ...
#
#                       product_type  price  special_price        department  \
# 33  micro-ondas acima de 30 litros      0              0  eletrodomésticos
# 59                           casal      0              0          colchões
# 68                           split      0              0  eletrodomésticos
#
#                  category                                                url  \
# 33            micro-ondas  http://www.ricardoeletro.com.br/Produto/Micro-...
# 59               cama box  http://www.ricardoeletro.com.br/Produto/Cama-B...
# 68  ar condicionado split  http://www.ricardoeletro.com.br/Produto/Ar-Con...
#
# ...

# %%
# Total of products on each variation
group = df.groupby('variation_label')
# Notice that we use size() and not count(). This is because count() applies the function to each column.
counts = group.size()
print "TOTALS PER GROUP:"
print counts
# Out:
# TOTALS PER GROUP:
# variation_label
#                                                    10194
# Antena Com Antena                                      1
# Aroma Fresh                                            1
# Aroma Fresh / Shimer                                   1
# Aroma Shimer                                           1
# Aroma Toque de Amaciante                               1
# Capacidade 1000L                                       2
# Capacidade 12000L e 14000L                             1
# Capacidade 2500L                                       2
# Capacidade 3 Pessoas                                   1
# Capacidade 3000L                                       1
# Capacidade 3700L                                       1
# Capacidade 4 Pessoas                                   2
# Capacidade 400L                                        1
# Capacidade 5 Pessoas                                   1
# Capacidade 5000L                                       1
# ...
