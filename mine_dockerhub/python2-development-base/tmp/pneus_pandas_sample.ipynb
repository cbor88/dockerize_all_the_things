# %%
import numpy as np

# %%
import pandas as pd

# %%
df = pd.read_csv('files/tyres.csv')

# %%
df = df.fillna(value='N/A')

# %%
df.count()
# Out:
# _id                       28124
# _meta.spider_name         28124
# url                       28124
# name                      28124
# sku                       28124
# image_url                 28124
# price                     28124
# special_price             28124
# instalments               28124
# instalment_value          28124
# available                 28124
# categories                28124
# brand                     28124
# model                     28124
# weight                    28124
# tyre__size_designation    28124
# tyre__rim_diameter        28124
# tyre__width               28124
# tyre__aspect_ratio        28124
# tyre__load_index          28124
# tyre__speed_rating        28124
# dtype: int64

# %%
df.columns
# Out:
# Index([u'_id', u'_meta.spider_name', u'url', u'name', u'sku', u'image_url', u'price', u'special_price', u'instalments', u'instalment_value', u'available', u'categories', u'brand', u'model', u'weight', u'tyre__size_designation', u'tyre__rim_diameter', u'tyre__width', u'tyre__aspect_ratio', u'tyre__load_index', u'tyre__speed_rating'], dtype='object')

# %%
selected_df = df.columns[[u'_meta.spider_name',u'_id', u'sku', u'url', u'name', u'brand', u'tyre__rim_diameter', u'tyre__load_index', u'tyre__speed_rating']]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-8-8212bdf8f1b1> in <module>()
# ----> 1 selected_df = df.columns[[u'_meta.spider_name',u'_id', u'sku',  u'url', u'name', u'brand', u'tyre__rim_diameter', u'tyre__load_index', u'tyre__speed_rating']]
#
# /usr/lib/python2.7/dist-packages/pandas/core/index.pyc in __getitem__(self, key)
#     622                 key = np.asarray(key)
#     623
# --> 624             result = arr_idx[key]
#     625             if result.ndim > 1:
#     626                 return result
#
# IndexError: unsupported iterator index

# %%
df._meta.spider_name
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-c91686c91722> in <module>()
# ----> 1 df._meta.spider_name
#
# /usr/lib/python2.7/dist-packages/pandas/core/generic.pyc in __getattr__(self, name)
#    1813                 return self[name]
#    1814             raise AttributeError("'%s' object has no attribute '%s'" %
# -> 1815                                  (type(self).__name__, name))
#    1816
#    1817     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute '_meta'

# %%
df.sku
# Out:
# 0           N/A
# 1     110641239
# 2     110641255
# 3     110641298
# 4     110641319
# 5     110641335
# 6     110641351
# 7     110641378
# 8     110641394
# 9     110641415
# 10    112282671
# 11    113097056
# 12    113097072
# 13    113097099
# 14    116805003
# ...
# 22318    N/A
# 22319    N/A
# 22320    N/A
# 22321    N/A
# 22322    N/A
# 22323    N/A
# 22324    N/A
# 22325    N/A
# 22326    N/A
# 22327    N/A
# 22328    N/A
# 22329    N/A
# 22330    N/A
# 22331    N/A
# 22332    N/A
# Name: sku, Length: 22333, dtype: object

# %%
df.brand
# Out:
# 0          N/A
# 1      Pirelli
# 2      Pirelli
# 3      Pirelli
# 4      Pirelli
# 5      Pirelli
# 6      Pirelli
# 7      Pirelli
# 8      Pirelli
# 9      Pirelli
# 10     Pirelli
# 11     Pirelli
# 12     Pirelli
# 13     Pirelli
# 14    Michelin
# ...
# 28109    Continental
# 28110    Continental
# 28111        Euzkadi
# 28112        Euzkadi
# 28113        Euzkadi
# 28114        Euzkadi
# 28115        Euzkadi
# 28116        Euzkadi
# 28117        Euzkadi
# 28118        Euzkadi
# 28119        Euzkadi
# 28120        Euzkadi
# 28121        Euzkadi
# 28122      Firestone
# 28123        Pirelli
# Name: brand, Length: 28124, dtype: object

# %%
sort(df.brand.unique)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-0f0c491f029e> in <module>()
# ----> 1 sort(df.brand.unique)
#
# NameError: name 'sort' is not defined

# %%
type(df.brand.unique)
# Out:
# instancemethod

# %%
df.brand.unique().sort()

# %%
all_brands = df.brand.unique()

# %%
all_brands
# Out:
# array(['Bridgestone', 'Pirelli', 'Michelin', 'N/A', 'Sunitrac', 'Toyo',
#        'Falken', 'Dunlop', 'Ceat', 'Marshal', 'Kumho', 'pirelli',
#        'PIRELLI', 'Aeolus', 'Seiberling', 'Firestone', 'Continental',
#        'Barum', 'Maxxis', 'Hankook', 'Goodyear', 'Kelly', 'Champiro',
#        'Nexen', 'BF Goodrich', 'GT Radial', 'KUMHO', 'Landsail', 'Nankang',
#        'Delinte', 'Europeu', 'Gt Radial', 'Sunny', 'Sailun', 'Triangle',
#        'Hifly', 'LingLong', 'ornet', 'hero', 'Viking', 'Metzeler',
#        'VIKING', 'Roadstone', 'Yokohama', 'Achilles', 'MICHELIN', 'AEOLUS',
#        'General Tire', 'Horizon', 'Timberline', 'Tornel', 'General',
#        'Hero', 'NEXEN', 'KELLY', 'Heliar', 'Kraft', 'Optima', 'Maxine',
#        'Engforth', 'NavCity', 'Navitech', 'Tramigo', 'Philips', 'VTO',
#        'DHF', 'Eqmax', 'Keko', 'Flash Cover', 'Hi Pull', 'Autoliner',
#        'Carmix', 'Bardahl', 'CAST Sports Sciencerol', 'Pneu Maggion',
# ...

# %%
all_brands.sort()

# %%
sorted = all_brands.sort()

# %%
sorted

# %%
type(sorted)
# Out:
# NoneType

# %%
all_brands
# Out:
# array(['ADERENZA', 'ADVANCE', 'AEOLUS', 'AR70', 'Achilles', 'Aderenza',
#        'Aeolus', 'Aliperti', 'Alux', 'American Auto', 'Atturo',
#        'Auto Shine', 'AutoShine', 'Autoliner', 'BCT Tire', 'BF Goodrich',
#        'BRW', 'Bardahl', 'Barum', 'Bepo', 'Bocol', 'Bomber', 'Bosal',
#        'Bosch', 'Bravox', 'Bridgestone', 'Brilland Tires',
#        'CAST Sports Sciencerol', 'CEAT', 'CHENGSHAN', 'CONSTANCY',
#        'CONTINENTAL', 'Camper', 'Carmix', 'Carreteiro', 'Caska', 'Ceat',
#        'Champiro', 'Chengshan', 'Chimpa', 'Clarion', 'Clear',
#        'Conjunto TireShop', 'Continental', 'DHF', 'DRC', 'Delinte',
#        'Double Star', 'Dunlop', 'Dyna', 'Eibach', 'Engforth', 'Eqmax',
#        'Eros', 'Estamparia Paulista', 'Europeu', 'FATE', 'Falken', 'Fate',
#        'Ferraro Rodas', 'Firestone', 'Flash Cover', 'Fullway', 'Fumagali',
#        'GA Flex', 'GENERAL', 'GOODRIDE', 'GT Radial', 'GT Sound', 'Garmin',
# ...

# %%
len(all_brands)
# Out:
# 264

# %%
brands_unique = []

# %%
brands_unique = set()

# %%
brands

# %%
brands_unique = []

# %%
for brand in all_brands:
    found = False
    for unique in brands_unique:
        if brand.lower() == unique.lower():
            found = True
            break
    if not found:
        brands_unique.append(brand)

# %%
len(brands_unique)
# Out:
# 241

# %%
brands_unique
# Out:
# ['ADERENZA',
#  'ADVANCE',
#  'AEOLUS',
#  'AR70',
#  'Achilles',
#  'Aliperti',
#  'Alux',
#  'American Auto',
#  'Atturo',
#  'Auto Shine',
#  'AutoShine',
#  'Autoliner',
#  'BCT Tire',
#  'BF Goodrich',
#  'BRW',
#  'Bardahl',
#  'Barum',
#  'Bepo',
#  'Bocol',
#  'Bomber',
#  'Bosal',
#  'Bosch',
#  'Bravox',
#  'Bridgestone',
#  'Brilland Tires',
#  'CAST Sports Sciencerol',
#  'CEAT',
#  'CHENGSHAN',
#  'CONSTANCY',
#  'CONTINENTAL',
#  'Camper',
#  'Carmix',
#  'Carreteiro',
#  'Caska',
#  'Champiro',
#  'Chimpa',
#  'Clarion',
#  'Clear',
#  'Conjunto TireShop',
#  'DHF',
#  'DRC',
#  'Delinte',
#  'Double Star',
#  'Dunlop',
#  'Dyna',
#  'Eibach',
#  'Engforth',
#  'Eqmax',
#  'Eros',
#  'Estamparia Paulista',
#  'Europeu',
#  'FATE',
#  'Falken',
#  'Ferraro Rodas',
#  'Firestone',
#  'Flash Cover',
#  'Fullway',
#  'Fumagali',
#  'GA Flex',
#  'GENERAL',
#  'GOODRIDE',
#  'GT Radial',
#  'GT Sound',
#  'Garmin',
#  'General Tire',
#  'Goodyear',
#  'H-Buster',
#  'HD',
# ...

# %%
df[df['brand'].isin(['ADERENZA'])]
# Out:
#                     _id _meta.spider_name  \
# 17447  pneu_plus-337800         pneu_plus
# 17448  pneu_plus-337927         pneu_plus
#
#                                                      url  \
# 17447  http://www.pneuplusonline.com.br/Pneu/Aderenza...
# 17448  http://www.pneuplusonline.com.br/Pneu/Aderenza...
#
#                                        name  sku  \
# 17447  Pneu Aderenza ADEZA66 195/60 R15 88V  N/A
# 17448  Pneu Aderenza ADZA99 265/50 R20 114V  N/A
#
#                                                image_url price special_price  \
# 17447  http://www.ecompleto.com.br/i/fp/77/337800_121...   N/A           N/A
# 17448  http://www.ecompleto.com.br/i/fp/77/337927_121...   N/A           N/A
#
#       instalments instalment_value available  categories     brand   model  \
# 17447         N/A              N/A     False  [ "Pneu" ]  ADERENZA     A66
# 17448         N/A              N/A     False  [ "Pneu" ]  ADERENZA  ADZA99
#
# ...

# %%
df[df['brand'].isin(['ADERENZA'])]['url'].values
# Out:
# array([ 'http://www.pneuplusonline.com.br/Pneu/Aderenza/ADEZA66/Aro-15/pneu-aderenza-adeza66-195-60-r15-88v___337800-SIT.html',
#        'http://www.pneuplusonline.com.br/Pneu/Aderenza/ADZA99/pneu-aderenza-adza99-265-50-r20-114v___337927-SIT.html'], dtype=object)

# %%
df[df['brand'].isin(['ADVANCE'])]
# Out:
#                  _id _meta.spider_name  \
# 17237  pneu_free-309         pneu_free
# 17238  pneu_free-310         pneu_free
# 17239  pneu_free-317         pneu_free
# 17300  pneu_free-552         pneu_free
# 17301  pneu_free-553         pneu_free
# 17416  pneu_free-775         pneu_free
# 17417  pneu_free-776         pneu_free
# 17418  pneu_free-777         pneu_free
#
#                                                      url  \
# 17237  http://www.pneufree.com.br/vendas/agricola/10....
# 17238  http://www.pneufree.com.br/vendas/agricola/11L...
# 17239  http://www.pneufree.com.br/vendas/agricola/17....
# 17300  http://www.pneufree.com.br/vendas/agricola/12....
# 17301  http://www.pneufree.com.br/vendas/agricola/14....
# 17416  http://www.pneufree.com.br/vendas/industrial/7...
# 17417  http://www.pneufree.com.br/vendas/industrial/2...
# 17418  http://www.pneufree.com.br/vendas/industrial/7...
#
#                                                     name  sku image_url  \
# ...

# %%
df[df['brand'].isin(['ADVANCE'])]['url'].values
# Out:
# array([ 'http://www.pneufree.com.br/vendas/agricola/10.5/65/16/14Lonas/130A6/HF1A/ADVANCE',
#        'http://www.pneufree.com.br/vendas/agricola/11L/16/12Lonas/116A8/F3/ADVANCE',
#        'http://www.pneufree.com.br/vendas/agricola/17.5/25/16Lonas/177-158B/E3-L3/ADVANCE',
#        'http://www.pneufree.com.br/vendas/agricola/12.00/20/16Lonas/169A2/C1A/ADVANCE',
#        'http://www.pneufree.com.br/vendas/agricola/14.00/24/16Lonas/177-153A8/G2-L2/ADVANCE',
#        'http://www.pneufree.com.br/vendas/industrial/7.00/12/14Lonas/142A7/PREMIUM-GRIP-II-(Completo)/ADVANCE',
#        'http://www.pneufree.com.br/vendas/industrial/28x9/15/14Lonas/154A7/PREMIUM-GRIP-II-(Completo)/ADVANCE',
#        'http://www.pneufree.com.br/vendas/industrial/7.00/15/14Lonas/151A7/PREMIUM-GRIP-II-(Completo)/ADVANCE'], dtype=object)

# %%
df[df['brand'].isin(['AEOLUS'])]['url'].values
# Out:
# array([ 'http://www.casasbahia.com.br/automotivo/PneusRodasCalotas/Pneus/PNEU-185R14C-AL01-AEOLUS-102-100R-3487702.html?recsource=busca-int&rectype=busca-836',
#        'http://www.casasbahia.com.br/automotivo/PneusRodasCalotas/Pneus/PNEU-185-60-R-14-AH01-AEOLUS-82H-2938886.html?recsource=busca-int&rectype=busca-836',
#        'http://www.casasbahia.com.br/automotivo/PneusRodasCalotas/Pneus/PNEU-205-60-R-16-AH01-AEOLUS-92H-2938889.html?recsource=busca-int&rectype=busca-836',
#        'http://www.pontofrio.com.br/automotivo/PneusRodasCalotas/Pneus/PNEU-185R14C-AL01-AEOLUS-102-100R-3487702.html?recsource=busca-int&rectype=busca-836',
#        'http://www.pontofrio.com.br/automotivo/PneusRodasCalotas/Pneus/PNEU-185-60-R-14-AH01-AEOLUS-82H-2938886.html?recsource=busca-int&rectype=busca-836',
#        'http://www.pontofrio.com.br/automotivo/PneusRodasCalotas/Pneus/PNEU-205-60-R-16-AH01-AEOLUS-92H-2938889.html?recsource=busca-int&rectype=busca-836'], dtype=object)

# %%
df[df['brand'].isin(['AR70'])]['url'].values
# Out:
# array([ 'http://www.gbgpneus.com.br/dvd-automotivo-ar70-710a-2-din-tela-7equot-touch-screen-bluetooth-usb-sd-sintonizador-ar70.html'], dtype=object)

# %%
df[df['brand'].isin(['Achilles'])]['url'].values
# Out:
# array([ 'http://www.autoz.com.br/Shopping/Loja/Detalhes/default.asp?Depto=1&ItemID=1&ProdutoID=25039',
#        'http://www.pneuplusonline.com.br/Pneu/Achiles/ATR-Sport/Aro-16/pneu-achilles-atr-sport-195-55-r15-85v___549572-SIT.html',
#        'http://www.tireshop.com.br/ProdutosDetalheComum.aspx?param1=1197',
#        'http://www.tireshop.com.br/ProdutosDetalheComum.aspx?param1=1205',
#        'http://www.tireshop.com.br/ProdutosDetalheComum.aspx?param1=1206',
#        'http://www.tireshop.com.br/ProdutosDetalheComum.aspx?param1=1207',
#        'http://www.tireshop.com.br/ProdutosDetalheComum.aspx?param1=1208',
#        'http://www.tireshop.com.br/ProdutosDetalheComum.aspx?param1=1209',
#        'http://www.tireshop.com.br/ProdutosDetalheComum.aspx?param1=1210',
#        'http://www.tireshop.com.br/ProdutosDetalheComum.aspx?param1=1211',
#        'http://www.tireshop.com.br/ProdutosDetalheComum.aspx?param1=1212',
# ...

# %%
df[df['brand'].isin(['N/A'])]['url'].values
# Out:
# array([ 'http://www.americanas.com.br/produto/116805249/pneu-bfgoorich-aro-15-235-75-r15-104s-tl-all-terrain-t-a-ko',
#        'http://www.americanas.com.br/produto/116805265/pneu-bfgoorich-aro-15-31x10.50-r15-109s-tl-all-terrain-t-a-ko',
#        'http://www.americanas.com.br/produto/116805302/pneu-bfgoorich-aro-16-245-70-r16-113s-tl-all-terrain-t-a-ko',
#        ...,
#        'http://www.pontofrio.com.br/automotivo/SomAutomotivo/Altofalantes/Par-de-Auto-Falantes-Bomber-Destroyer-Quadriaxial-6x9-150W-RMS-2963392.html?recsource=busca-int&rectype=busca-836',
#        'http://www.pontofrio.com.br/automotivo/SomAutomotivo/Altofalantes/Par-de-Auto-Falantes-Bomber-Destroyer-Quadriaxial-6x9-110W-RMS-2963393.html?recsource=busca-int&rectype=busca-836',
#        'http://www.pontofrio.com.br/automotivo/SomAutomotivo/Altofalantes/Kit-2-Vias-6-Pol.-100W-RMS---JBLSelenium-62V5A-3009778.html?recsource=busca-int&rectype=busca-836'], dtype=object)

# %%
len(df[df['brand'].isin(['N/A'])]['url'].values)
# Out:
# 6894

# %%
df[df['brand'].isin(['Alux'])]['url'].values
# Out:
# array([ 'http://www.pneustore.com.br/produto/809-roda-8-25-x-22-5-aluminio-ht2230bbm-alux',
#        'http://www.pneustore.com.br/produto/1331-roda-8-25x22-5-aluminio-ht2230-mf-semibrilho-alux'], dtype=object)

# %%
df[df['brand'].isin(['American Auto'])]['url'].values
# Out:
# array([ 'http://www.gbgpneus.com.br/soquete-extensor-com-3-saidas-de-acendedor-de-cigarro-american-auto.html'], dtype=object)

# %%
 df[df['brand'].isin(['Atturo'])]['url'].values
# Out:
# array(['http://www.tireshop.com.br/ProdutosDetalheComum.aspx?param1=1763',
#        'http://www.tireshop.com.br/ProdutosDetalheComum.aspx?param1=1764',
#        'http://www.tireshop.com.br/ProdutosDetalheComum.aspx?param1=1765',
#        'http://www.tireshop.com.br/ProdutosDetalheComum.aspx?param1=1766',
#        'http://www.tireshop.com.br/ProdutosDetalheComum.aspx?param1=1767',
#        'http://www.tireshop.com.br/ProdutosDetalheComum.aspx?param1=1768',
#        'http://www.tireshop.com.br/ProdutosDetalheComum.aspx?param1=1769',
#        'http://www.tireshop.com.br/ProdutosDetalheComum.aspx?param1=1770',
#        'http://www.tireshop.com.br/ProdutosDetalheComum.aspx?param1=1771',
#        'http://www.tireshop.com.br/ProdutosDetalheComum.aspx?param1=1772',
#        'http://www.tireshop.com.br/ProdutosDetalheComum.aspx?param1=1773',
#        'http://www.tireshop.com.br/ProdutosDetalheComum.aspx?param1=1774',
# ...

# %%
 df[df['brand'].isin(['Auto Shine'])]['url'].values
# Out:
# array([ 'http://www.gbgpneus.com.br/kit-quick-shine-cera-liquida-500ml-mais-pano-de-microfibra-auto-shine.html'], dtype=object)

# %%
 df[df['brand'].isin(['AutoShine'])]['url'].values
# Out:
# array(['http://www.itaro.com.br/cera-liquida-autoshine/',
#        'http://www.itaro.com.br/refresh-gel-autoshine-tutti-frutti/',
#        'http://www.itaro.com.br/refresh-gel-autoshine-pear-femme/',
#        'http://www.itaro.com.br/refresh-gel-autoshine-play/',
#        'http://www.itaro.com.br/refresh-gel-autoshine-marine/',
#        'http://www.itaro.com.br/refresh-gel-autoshine-chrome/',
#        'http://www.itaro.com.br/refresh-gel-autoshine-angelical/',
#        'http://www.itaro.com.br/refresh-gel-autoshine-cupcake/',
#        'http://www.itaro.com.br/refresh-gel-autoshine-t-adore/',
#        'http://www.itaro.com.br/refresh-gel-autoshine-aromat/',
#        'http://www.itaro.com.br/refresh-gel-autoshine-lavanda/',
#        'http://www.itaro.com.br/emborrachamento-liquido-autoshine-dip-shine-amarelo-fluor/',
#        'http://www.itaro.com.br/emborrachamento-liquido-autoshine-dip-shine-azul-bugatti/',
# ...

# %%
 df[df['brand'].isin(['Autoliner'])]['url'].values
# Out:
# array([ 'http://www.gbgpneus.com.br/protetor-de-cacamba-autoliner-nissan-frontier-cabine-dupla-2008-em-diante-autoliner.html',
#        'http://www.gbgpneus.com.br/protetor-de-cacamba-autoliner-toyota-hilux-cabine-dupla-2005-em-diante-sem-aba-autoliner.html',
#        'http://www.gbgpneus.com.br/protetor-de-cacamba-autoliner-mitsubishi-l200-gls-ate-2007-cabine-dupla-autoliner.html',
#        'http://www.gbgpneus.com.br/protetor-de-cacamba-autoliner-gm-montana-autoliner.html',
#        'http://www.gbgpneus.com.br/protetor-de-cacamba-autoliner-gm-s10-cabine-dupla-sem-aba-autoliner.html',
#        'http://www.gbgpneus.com.br/protetor-de-cacamba-autoliner-gm-s10-cabine-simples-sem-aba-autoliner.html',
#        'http://www.gbgpneus.com.br/protetor-de-cacamba-autoliner-ford-ranger-cabine-dupla-sem-aba-ate-2011-autoliner.html',
#        'http://www.gbgpneus.com.br/protetor-de-cacamba-autoliner-gm-s10-cabine-simples-com-aba-autoliner.html',
# ...

# %%
 df[df['brand'].isin(['BCT Tire'])]['url'].values
# Out:
# array(['http://www.kdpneus.com.br/pneu-aro-16---215-60r16---s600---95h---bct/p',
#        'http://www.kdpneus.com.br/pneu-bct-aro-15---195-50r15---s900---82v/p'], dtype=object)

# %%
 df[df['brand'].isin(['BRW'])]['url'].values
# Out:
# array([ 'http://www.gbgpneus.com.br/roda-brw-aro-14-brw180-14x60-prata-4-furos-x-100-mm-et-mais42-brw.html',
#        'http://www.gbgpneus.com.br/roda-brw-aro-14-brw370-14x60-prata-4-furos-x-100-mm-et-mais35-brw.html',
#        'http://www.gbgpneus.com.br/roda-brw-aro-14-brw380-14x60-fosco-diamantado-multi-4-furos-x-100108-mm-et-mais35-brw.html',
#        'http://www.gbgpneus.com.br/roda-brw-aro-14-brw450-14x60-preta-diamantada-multi-4-furos-x-100108-mm-et-mais35-brw.html',
#        'http://www.gbgpneus.com.br/roda-brw-aro-14-brw490-14x60-preta-diamantada-4-furos-x-99-mm-et-mais35-brw.html',
#        'http://www.gbgpneus.com.br/roda-brw-aro-14-brw570-14x60-hiper-prata-multi-4-furos-x-100108-mm-et-mais35-brw.html',
#        'http://www.gbgpneus.com.br/roda-brw-aro-14-brw580-14x60-prata-multi-45-furos-x-100-mm-et-mais35-brw.html',
#        'http://www.gbgpneus.com.br/roda-brw-aro-15-brw450-15x60-preto-diamantado-multi-4-furos-x-99108-mm-et-mais35-brw.html',
# ...

# %%
 df[df['brand'].isin(['Bardahl'])]['url'].values
# Out:
# array([ 'http://www.gbgpneus.com.br/aditivo-clean-gas-para-limpeza-de-motores-gasolina-200ml-bardahl.html',
#        'http://www.gbgpneus.com.br/aditivo-flush-para-limpeza-de-motores-gasolina-alcool-diesel-gnv-500ml-bardahl.html',
#        'http://www.gbgpneus.com.br/aditivo-gasolina-alcool-bicombustivel-flex-200ml-bardahl.html',
#        'http://www.gbgpneus.com.br/aditivo-para-motores-diesel-b12-turbo-1-litro-bardahl.html',
#        'http://www.gbgpneus.com.br/aditivo-para-motores-gasolina-alcool-gnv-b12-plus-500ml-bardahl.html',
#        'http://www.gbgpneus.com.br/aditivo-para-oleo-diesel-max-diesel-200ml-bardahl.html',
#        'http://www.gbgpneus.com.br/aditivo-prolonga-para-motores-gasolina-alcool-gnv-diesel-500ml-bardahl.html',
#        'http://www.gbgpneus.com.br/max-power-buster-aditivo-para-motores-gasolina-200ml-bardahl.html',
#        'http://www.gbgpneus.com.br/power-racing-aditivo-para-motores-gasolina-alcool-500ml-bardahl.html',
# ...

# %%
 df[df['brand'].isin(['Barum'])]['url'].values
# Out:
# array([ 'http://www.americanas.com.br/produto/7847673/pneu-barum-brillantis-2-175-70r13-82t',
#        'http://www.americanas.com.br/produto/7847674/pneu-bravuris-2-195-60r15-88h-barum',
#        'http://www.americanas.com.br/produto/7847675/pneu-brillantis-2-165-70r13-79t-barum',
#        'http://www.americanas.com.br/produto/7847732/pneu-brillantis-2-175-70r14-84t-barum',
#        'http://www.americanas.com.br/produto/7847737/pneu-barum-brillantis-2-175-65r14-82t',
#        'http://www.americanas.com.br/produto/7847780/pneu-barum-brillantis-2-185-60r15-88h',
#        'http://www.americanas.com.br/produto/7847785/pneu-barum-bravuris-2-195-55r15-85v',
#        'http://www.americanas.com.br/produto/7847787/pneu-bravuris-2-205-65r15-94h-barum',
#        'http://www.americanas.com.br/produto/8140064/kit-4-pneus-barum-brillantis-2-175-65r14-82t-',
# ...

# %%
 df[df['brand'].isin(['Bocol'])]['url'].values
# Out:
# array(['http://www.itaro.com.br/tapete-carro-interlago/'], dtype=object)

# %%
 df[df['brand'].isin(['Bosal'])]['url'].values
# Out:
# array(['http://www.itaro.com.br/macaco-bosal-sanfonado/',
#        'http://www.itaro.com.br/macaco-bosal-joelho/'], dtype=object)

# %%
 df[df['brand'].isin(['Brilland Tires'])]['url'].values
# Out:
# array([ 'http://www.kdpneus.com.br/pneu-briland--aro-13---155-65r13---brp-605----73t---pneu--chery-qq-br1556513/p'], dtype=object)

# %%
 df[df['brand'].isin(['CAST Sports Sciencerol'])]['url'].values
# Out:
# array([ 'http://www.gbgpneus.com.br/oleo-lubrificante-castrol-gtx-ecoflex-15w40-sl-1-litro-castrol.html',
#        'http://www.gbgpneus.com.br/oleo-lubrificante-castrol-magnatec-10w40-1-litro-castrol.html',
#        'http://www.gbgpneus.com.br/oleo-lubrificante-castrol-gtx-5x-20w50-sl-1-litro-castrol.html',
#        'http://www.gbgpneus.com.br/oleo-lubrificante-castrol-tection-15w40-1-litro-castrol.html',
#        'http://www.gbgpneus.com.br/oleo-lubrificante-castrol-edge-sport-0w40-1-litro-castrol.html',
#        'http://www.gbgpneus.com.br/oleo-lubrificante-castrol-edge-sport-5w30-1-litro-castrol.html',
#        'http://www.gbgpneus.com.br/oleo-lubrificante-castrol-mtf-ep-90-1-litro-castrol.html',
#        'http://www.gbgpneus.com.br/oleo-lubrificante-castrol-magnatec-flex-15w40-1-litro-castrol.html'], dtype=object)

# %%
 df[df['brand'].isin(['CEAT'])]['url'].values
# Out:
# array([ 'http://www.pneustore.com.br/produto/683-pneu-7-50-16-fm-super-ceat-12pr-120-116k',
#        'http://www.pneustore.com.br/produto/770-pneu-10-00-20-fleet-master-ceat-16pr-145-141k',
#        'http://www.pneustore.com.br/produto/318-pneu-11-00-22-rama-ii-ceat-16pr-152-146',
#        'http://www.pneustore.com.br/produto/774-pneu-275-80r22-5-pro-r10-ceat-149-146l',
#        'http://www.pneustore.com.br/produto/432-pneu-295-80r22-5-pro-r10-ceat-152-148m',
#        'http://www.pneustore.com.br/produto/677-pneu-10-00-r-20-pro-s10-ceat-146-143k',
#        'http://www.pneustore.com.br/produto/743-pneu-185-65-r-14-milaze-ceat-tl-86t',
#        'http://www.pneustore.com.br/produto/448-pneu-175-70r13-82t-milaze-tl-ceat',
#        'http://www.pneustore.com.br/produto/447-pneu-175-65r14-milaze-tl-ceat-82t',
#        'http://www.pneustore.com.br/produto/687-pneu-185-70r14-milaze-ceat-88t',
#        'http://www.pneustore.com.br/produto/408-pneu-600-50-22-5-t422-ceat-16pr-tl-flotation',
# ...

# %%
 df[df['brand'].isin(['GT Radial'])]['url'].values
# Out:
# array([ 'http://www.americanas.com.br/produto/7848500/pneu-maxmiler-cx-195-75r16c-8pr-107-105r-gt-radial',
#        'http://www.casasbahia.com.br/automotivo/PneusRodasCalotas/Pneus/GT-Radial-Savero-M-T--265-75R16-116T--2294462.html?recsource=busca-int&rectype=busca-836',
#        'http://www.casasbahia.com.br/automotivo/PneusRodasCalotas/Pneus/GT-Radial-Maxmiler-CX--195-75R16C-8PR-107-105R--2294522.html?recsource=busca-int&rectype=busca-836',
#        'http://www.casasbahia.com.br/automotivo/PneusRodasCalotas/Pneus/GT-Radial-Savero-A-T-Plus--225-75R15-102T--2294530.html?recsource=busca-int&rectype=busca-836',
#        'http://www.casasbahia.com.br/automotivo/PneusRodasCalotas/Pneus/GT-Radial-Maxmiler-CX--225-70R15C-8PR-112-110R--2476393.html?recsource=busca-int&rectype=busca-836',
#        'http://www.itaro.com.br/gt-radial-gtx-60-205-60r15-91v/',
#        'http://www.itaro.com.br/champiro-bax-215-60-r16-95v/',
#        'http://www.itaro.com.br/champiro-eco-175-70-r14-84h/',
# ...

# %%
 df[df['brand'].isin(['Flash Cover'])]['url'].values
# Out:
# array([ 'http://www.gbgpneus.com.br/capota-maritima-flash-cover-baguete-gm-corsa-pickup-flash-cover.html',
#        'http://www.gbgpneus.com.br/capota-maritima-flash-cover-baguete-dodge-dakota-cabine-simples-flash-cover.html',
#        'http://www.gbgpneus.com.br/capota-maritima-flash-cover-baguete-toyota-hilux-cabine-dupla-ate-2004-flash-cover.html',
#        'http://www.gbgpneus.com.br/capota-maritima-flash-cover-baguete-toyota-hilux-cabine-simples-ate-2004-flash-cover.html',
#        'http://www.gbgpneus.com.br/capota-maritima-flash-cover-baguete-mitsubishi-l200-com-grade-original-flash-cover.html',
#        'http://www.gbgpneus.com.br/capota-maritima-flash-cover-baguete-mitsubishi-l200-triton-flash-cover.html',
#        'http://www.gbgpneus.com.br/capota-maritima-flash-cover-baguete-gm-montana-flash-cover.html',
#        'http://www.gbgpneus.com.br/capota-maritima-flash-cover-baguete-nissan-navara-cabine-dupla-2008-em-diante-flash-cover.html',
# ...

# %%
 df[df['brand'].isin(['WeatherTech'])]['url'].values
# Out:
# array([ 'http://www.gbgpneus.com.br/tapete-weathertech-portamalas-mercedesbenz-ml350-ml550-ml500-e-ml63-amg-preto-weathertech.html',
#        'http://www.gbgpneus.com.br/tapete-weathertech-portamalas-hyundai-ix35-preto-weathertech.html',
#        'http://www.gbgpneus.com.br/tapete-weathertech-portamalas-hyundai-veracruz-preto-weathertech.html',
#        'http://www.gbgpneus.com.br/tapete-weathertech-portamalas-dodge-jorney-e-fiat-freemont-cinza-weathertech.html',
#        'http://www.gbgpneus.com.br/tapete-weathertech-portamalas-land-rover-discovery-3-e-4-preto-weathertech.html',
#        'http://www.gbgpneus.com.br/tapete-weathertech-portamalas-audi-q5-preto-weathertech.html',
#        'http://www.gbgpneus.com.br/tapete-weathertech-portamalas-audi-q5-cinza-weathertech.html',
#        'http://www.gbgpneus.com.br/tapete-weathertech-cabine-hyundai-tucson-dianteiro-mais-traseiro-preto-weathertech.html',
# ...

# %%
 df[df['brand'].isin(['Zetum'])]['url'].values
# Out:
# array(['http://www.pneustore.com.br/produto/3-pneu-195-50r15-zu37-zetum-82h',
#        'http://www.pneustore.com.br/produto/10-pneu-195-55r15-zu37-zetum-85v'], dtype=object)

# %%
 df[df['brand'].isin(['Pneu AX'])]['url'].values
# Out:
# array([ 'http://www.gbgpneus.com.br/pneu-ax-aro-16-750x16-ss200-direcional-120116k-12-lonas-pneu-ax.html',
#        'http://www.gbgpneus.com.br/pneu-ax-aro-16-750x16-ss100-tracao-120116k-12-lonas-pneu-ax.html'], dtype=object)

# %%
curr4+ Nutrition: 4 Plus, 4 Plus Nutrition\nArnold Series: Arnold Series (MusclePharm)\nAST Sports Science: AST\nAtlhetica Nutrition: Atlhetica, Atlh\u00e9tica, Atlhetica Evolution, Atlh\u00e9tica Evolution, Atlh\u00e9tica Nutrition\nBarlean's: Barlean`S\nBillabong: Billabong Girls\nBodyAction: Body Action\nBPI Sports: BPI\nCoach Sports Nutrition: Coach\nConverse: Converse Premium, Converse Skateboard\nDNA: D.N.A.\nDymatize: Dymatize Nutrition\nEpic Line: Epic\nIntegralm\u00e9dica: Integral Medica, Integralmedica\nIntlab: Intlab Suplementos\nLabrada: Labrada Nutrition\nLevi's: Levis\nMediervas: Mediervas Nutraceuticos\nMHP: MHP - Maximum Human Performance\nMusclePharm: Muscle Pharm\nNature's Best: Nature`S Best, Nature\u00b4s Best\nNature's Bounty: Natures Bounty\nNeoNutri: Neo Nutri\nNutrilatina: Nutrilatina AGE, Nutrilatina Rennovee\nOptimum Nutrition: Optimum\nPacific Health: PacificHealth\nPerformance Nutrition: Performance\nProbi\u00f3tica: Probiotica\nReebok: reebok fitness\nSalto's: Salto\u00b4S\nSmart Life: Smartlife\nSolaris Nutrition: Solaris\nSpeedo: Speedo Nutrition\nSportPharma: Sport Pharma\nStem Pharmaceutical: Stem\nSundown Naturals: Sundown Vitaminas\nUmbrella Labs: Umbrella\nBirdhouse Skateboards: Birdhouse\nBob Burnquist: burnquist\nCoca-Cola: Coca Cola\nTrack & Bikes: Track E Bikes, Track Bikes\nmaz4s: ma z4s\nmaz1: ma z1\nSP Touring T1: sptrgt1\nsport 270: sport270\nDueler: Dueller\nBCT Tire: BCT\nBF Goodrich: BFGoodrich\nLingLong: Ling Long\nWestLake: West Lake\nPrimeWell: Prime Well\nBarum: Barun\nGreen X: GRNXent = ''
# Out:
#   File "<ipython-input-121-6507c976af4a>", line 1
# ...

# %%
df[df['brand'].isin(['N/A'])][['url', '_meta.spider_name']]
# Out:
#                                                    url _meta.spider_name
# 26   http://www.americanas.com.br/produto/116805249...        americanas
# 27   http://www.americanas.com.br/produto/116805265...        americanas
# 29   http://www.americanas.com.br/produto/116805302...        americanas
# 30   http://www.americanas.com.br/produto/116805329...        americanas
# 31   http://www.americanas.com.br/produto/116805345...        americanas
# 34   http://www.americanas.com.br/produto/117248958...        americanas
# 35   http://www.americanas.com.br/produto/117248982...        americanas
# 36   http://www.americanas.com.br/produto/117249045...        americanas
# 37   http://www.americanas.com.br/produto/117249109...        americanas
# 38   http://www.americanas.com.br/produto/117249133...        americanas
# 39   http://www.americanas.com.br/produto/117249192...        americanas
# 40   http://www.americanas.com.br/produto/117249221...        americanas
# ...

# %%
len(df[df['brand'].isin(['N/A'])])
# Out:
# 7527

# %%
df.count()
# Out:
# _id                       28124
# _meta.spider_name         28124
# url                       28124
# name                      28124
# sku                       28124
# image_url                 28124
# price                     28124
# special_price             28124
# instalments               28124
# instalment_value          28124
# available                 28124
# categories                28124
# brand                     28124
# model                     28124
# weight                    28124
# tyre__size_designation    28124
# tyre__rim_diameter        28124
# tyre__width               28124
# tyre__aspect_ratio        28124
# tyre__load_index          28124
# tyre__speed_rating        28124
# dtype: int64

# %%
df[df['brand'].isin(['N/A'])][['url', '_meta.spider_name']]
# Out:
#                                                    url _meta.spider_name
# 26   http://www.americanas.com.br/produto/116805249...        americanas
# 27   http://www.americanas.com.br/produto/116805265...        americanas
# 29   http://www.americanas.com.br/produto/116805302...        americanas
# 30   http://www.americanas.com.br/produto/116805329...        americanas
# 31   http://www.americanas.com.br/produto/116805345...        americanas
# 34   http://www.americanas.com.br/produto/117248958...        americanas
# 35   http://www.americanas.com.br/produto/117248982...        americanas
# 36   http://www.americanas.com.br/produto/117249045...        americanas
# 37   http://www.americanas.com.br/produto/117249109...        americanas
# 38   http://www.americanas.com.br/produto/117249133...        americanas
# 39   http://www.americanas.com.br/produto/117249192...        americanas
# 40   http://www.americanas.com.br/produto/117249221...        americanas
# ...

# %%
752700 / 28124
# Out:
# 26
