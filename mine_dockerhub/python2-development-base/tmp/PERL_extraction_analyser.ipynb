# %%
import csv

import numpy as np
import pandas as pd

FILE = 'files/csvs/balao_da_informatica.csv'
# FILE = 'files/csvs/megamamute.csv'
SEPARATOR = ';'

df = pd.read_csv(FILE, SEPARATOR, error_bad_lines=False)
# df = pd.read_csv(FILE, SEPARATOR, error_bad_lines=False, quoting=csv.QUOTE_NONE)

# df = df.fillna(value='')

# %%
df.count()
# Out:
# SKU                    2257
# Nome                   2257
# Fabricante             2257
# Departamento Parser    2257
# Categoria              2257
# GTIN                   2215
# MPN                    2257
# Bytes                     0
# Litros                    0
# Tamanho                   0
# Qtd. Embalagem            0
# Cor                       0
# Peso                      0
# Genero                    0
# Volume                    0
# Voltagem                  0
# Disponibilidade           0
# Preco                  2257
# Preco oferta           2257
# Unnamed: 19               0
# Unnamed: 20               0
# Possibles EAN             0
# dtype: int64

# %%
df.columns
# Out:
# Index([u'SKU', u'Nome', u'Fabricante', u'Departamento Parser', u'Categoria',
#        u'GTIN', u'MPN', u'Bytes', u'Litros', u'Tamanho', u'Qtd. Embalagem',
#        u'Cor', u'Peso', u'Genero', u'Volume', u'Voltagem', u'Disponibilidade',
#        u'Preco', u'Preco oferta', u'Unnamed: 19', u'Unnamed: 20',
#        u'Possibles EAN'],
#       dtype='object')

# %%
esperados = "URL Consultada	SKU	Variacao pai	SKU pai	Nome	Fabricante	Tipo Produto	Departamento Parser	Departamento Crawler	Categoria Parser	Categoria Crawler	GTIN	MPN	Bytes	Litros	Tamanho	Qtd. Embalagem	Cor	Peso	Genero	Volume	Voltagem	Disponibilidade	Preco	Preco oferta	URL	Imagem	Possible SKUs	Possible EAN"

# %%
esperados.split('\t')
# Out:
# ['URL Consultada',
#  'SKU',
#  'Variacao pai',
#  'SKU pai',
#  'Nome',
#  'Fabricante',
#  'Tipo Produto',
#  'Departamento Parser',
#  'Departamento Crawler',
#  'Categoria Parser',
#  'Categoria Crawler',
#  'GTIN',
#  'MPN',
#  'Bytes',
#  'Litros',
#  'Tamanho',
#  'Qtd. Embalagem',
#  'Cor',
#  'Peso',
#  'Genero',
#  'Volume',
#  'Voltagem',
#  'Disponibilidade',
#  'Preco',
#  'Preco oferta',
#  'URL',
#  'Imagem',
#  'Possible SKUs',
#  'Possible EAN']

# %%
df.tail(5)
# Out:
#         SKU                                               Nome     Fabricante  \
# 2252  91443  Placa de V�deo PowerColor Radeon R7 250X (2GBD...    POWER COLOR
# 2253  91444  Kit Teclado e Mouse Cooler Master Storm Devast...  Cooler Master
# 2254  91445  Placa de V�deo Asus Radeon R7 360 OC Edition (...           ASUS
# 2255  91446  Placa de V�deo Asus Radeon R7 370 STRIX OC Edi...           ASUS
# 2256  91447                 Smartphone Galaxy Win Duos (I8552)        SAMSUNG
#
#      Departamento Parser                  Categoria      GTIN  \
# 2252         Inform�tica  Placas de V�deo e Captura       NaN
# 2253         Inform�tica                    Teclado  4,72E+12
# 2254         Inform�tica  Placas de V�deo e Captura  4,71E+12
# 2255         Inform�tica  Placas de V�deo e Captura  4,71E+12
# 2256         Smartphones                 Smartphone       NaN
#
#                     MPN  Bytes  Litros  Tamanho      ...        Peso  Genero  \
# ...
