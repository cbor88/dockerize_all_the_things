# %%
import csv

arcond_file = csv.DictReader(open("files/classifier/crawler_arcondicionados_extra.csv"))
for row in arcond_file:
    print row
# Out:
# {'product_name': 'Ar-Condicionado Split Samsung Max Plus AQ09UWBUXAZ Quente/Frio 9.000 BTUs - 220V (Unidade interna e externa)', ' product_type': 'ar_condicionado'}
# {'product_name': 'Ar Condicionado 18000 BTU`s Split Silent Frio Elgin - 220v', ' product_type': 'ar_condicionado'}
# {'product_name': 'Ar Condicionado Cassete Elgin 60.000 Btus Frio Trif\xc3\xa1sico - 220V', ' product_type': 'ar_condicionado'}
# {'product_name': 'Ar Condicionado Consul Split Hi Wall Bem Estar 22000 BTUs Quente/Frio CBZ22DBBNA - 220v', ' product_type': 'ar_condicionado'}
# {'product_name': 'Ar Condicionado Consul Split Inverter Bem Estar 12000 BTUs Frio CBF12CBBNA - 220v', ' product_type': 'ar_condicionado'}
# {'product_name': 'Ar Condicionado Consul Split Inverter Bem Estar 18000 BTUs Quente/Frio CBM18CBBNA - 220v', ' product_type': 'ar_condicionado'}
# {'product_name': 'Ar Condicionado Consul Split Inverter Bem Estar 9000 BTUs Quente/Frio CBM09CBBNA - 220v', ' product_type': 'ar_condicionado'}
# ...

# %%
import numpy as np
import pandas as pd

# %%
df_arcond = pd.read_csv('files/classifier/crawler_arcondicionados_extra.csv')
df_arcond = df_arcond.fillna(value='N/A')
df_arcond.count()
df_arcond.product_name.unique().sort()

# %%
df_arcond
# Out:
#                                          product_name     product_type
# 0   Ar-Condicionado Split Samsung Max Plus AQ09UWB...  ar_condicionado
# 1   Ar Condicionado 18000 BTU`s Split Silent Frio ...  ar_condicionado
# 2   Ar Condicionado Cassete Elgin 60.000 Btus Frio...  ar_condicionado
# 3   Ar Condicionado Consul Split Hi Wall Bem Estar...  ar_condicionado
# 4   Ar Condicionado Consul Split Inverter Bem Esta...  ar_condicionado
# 5   Ar Condicionado Consul Split Inverter Bem Esta...  ar_condicionado
# 6   Ar Condicionado Consul Split Inverter Bem Esta...  ar_condicionado
# 7   Ar Condicionado de Janela 10.000 btus Consul F...  ar_condicionado
# 8   Ar Condicionado Elgin Split Hi Wall Silent 180...  ar_condicionado
# 9   Ar Condicionado Janela Springer Silentia Eletr...  ar_condicionado
# 10  Ar Condicionado Janela Springer Silentia Eletr...  ar_condicionado
# 11  Ar Condicionado Janela Springer Silentia Manua...  ar_condicionado
# ...

# %%
df_pneus = pd.read_csv('files/classifier/crawler_pneus_varios_sites.csv')
df_pneus = df_pneus.fillna(value='N/A')
df_pneus.count()
df_pneus.product_name.unique().sort()

# %%
df_pneus
# Out:
#                                          product_name  product_type
# 0               Pneu Pirelli Aro 16 205/55R16 Phantom          pneu
# 1                    155R12C 8 Lonas 88/86P 857 KUMHO          pneu
# 2                      165/60R14 75H SOLUS KH15 KUMHO          pneu
# 3                    165/70R13 79T BRILLANTIS 2 BARUM          pneu
# 4                  175/70R13 82T ATREZZO SH406 SAILUN          pneu
# 5                      185/60R15 84H SOLUS KH25 KUMHO          pneu
# 6               195/50R15 82V SPORTCAT CSC5 CHENGSHAN          pneu
# 7                       195/55R15 85V LY688 CONSTANCY          pneu
# 8                        195/60R15 88H RP28  GOODRIDE          pneu
# 9          195/70R15C 8 Lonas 104/102R SC301 GOODRIDE          pneu
# 10                 195R14C 8 Lonas 106/104R 857 KUMHO          pneu
# 11  2 Pneus Yokohama Advan Sport V103 225/45 ZR17 ...          pneu
# 12                       205/40R17 84W SV308 GOODRIDE          pneu
# ...

# %%
type(df_arcond)
# Out:
# pandas.core.frame.DataFrame

# %%
df_arcond.to_json()
# Out:
# '{"product_name":{"0":"Ar-Condicionado Split Samsung Max Plus AQ09UWBUXAZ Quente\\/Frio 9.000 BTUs - 220V (Unidade interna e externa)","1":"Ar Condicionado 18000 BTU`s Split Silent Frio Elgin - 220v","2":"Ar Condicionado Cassete Elgin 60.000 Btus Frio Trif\\u00e1sico - 220V","3":"Ar Condicionado Consul Split Hi Wall Bem Estar 22000 BTUs Quente\\/Frio CBZ22DBBNA - 220v","4":"Ar Condicionado Consul Split Inverter Bem Estar 12000 BTUs Frio CBF12CBBNA - 220v","5":"Ar Condicionado Consul Split Inverter Bem Estar 18000 BTUs Quente\\/Frio CBM18CBBNA - 220v","6":"Ar Condicionado Consul Split Inverter Bem Estar 9000 BTUs Quente\\/Frio CBM09CBBNA - 220v","7":"Ar Condicionado de Janela 10.000 btus Consul Frio Mecanico Classe A CCB10","8":"Ar Condicionado Elgin Split Hi Wall Silent 18000 btus Frio c\\/ Controle Remoto - 220v","9":"Ar Condicionado Janela Springer Silentia Eletr\\u00f4nico 18.000 Btus Frio","10":"Ar Condicionado Janela Springer Silentia Eletr\\u00f4nico 21.000 Btus Frio","11":"Ar 
# ...
