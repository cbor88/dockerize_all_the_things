# %% [markdown]
# # Analysing an ENRICHED perl site extraction

# %%
import os
import numpy as np
import pandas as pd

# Consolidates vars for the other necessary paths
CSV_NAME = 'files/csvs/colombo_scraped.csv.CONVERTED.csv'

df = pd.read_csv(CSV_NAME, sep="\t", error_bad_lines=False)
df = df.fillna(value='N/A')

total_records = len(df)

print "quantidade de registros: ", str(total_records)
# Out:
# quantidade de registros:  2035

# %%
# Show all columns
df.columns
# Out:
# Index([u'_id.id', u'ean', u'brand', u'name', u'product_type', u'price',
#        u'special_price', u'department', u'category', u'url', u'available',
#        u'instalments', u'instalment_value', u'image_url', u'variation_label',
#        u'tyre.width', u'tyre.aspect_ratio', u'tyre.rim_diameter',
#        u'tyre.load_index', u'tyre.speed_rating'],
#       dtype='object')

# %%
# Show the first records
df.head(2)
# Out:
#    _id.id  ean brand                                               name  \
# 0  715040  N/A    LG  Smartphone LG Leon  3G  Dual Chip  TV Digital ...
# 1  766362  N/A   N/A  Smartphone Motorola Moto G 3ª Geração HDTV 16G...
#
#   product_type  price  special_price department    category  \
# 0           LG  529.9          499.9  Telefonia  Smartphone
# 1     Motorola  999.0          899.1  Telefonia  Smartphone
#
#                                                  url available instalments  \
# 0  http://www.colombo.com.br/produto/Telefonia/Sm...      True          10
# 1  http://www.colombo.com.br/produto/Telefonia/Sm...      True          10
#
#   instalment_value                                          image_url  \
# 0            52.99  http://images.colombo.com.br/produtos/715040/7...
# 1             99.9  http://images.colombo.com.br/produtos/766362/7...
#
#   variation_label tyre.width tyre.aspect_ratio tyre.rim_diameter  \
# ...

# %%
tyre = df['tyre.width']
tyre.describe()
# Out:
# count     2035
# unique       9
# top        N/A
# freq      2023
# Name: tyre.width, dtype: object

# %%
sorted(df['department'].unique())
# Out:
# ['Acess\xc3\xb3rios',
#  'Automotivo',
#  'Bazar',
#  'Brinquedos',
#  'Cine Foto',
#  'Eletrodom\xc3\xa9sticos',
#  'Esporte e Lazer',
#  'Ferramentas',
#  'Games',
#  'Inform\xc3\xa1tica',
#  'M\xc3\xb3veis',
#  'Port\xc3\xa1teis',
#  'Sa\xc3\xbade e Beleza',
#  'Som e V\xc3\xaddeo',
#  'Telefonia']

# %%
# url_df.to_csv('{}.FINAL.csv'.format(CSV_NAME), sep='\t', orient='records', index=False)
# url_df.to_csv('{}.FINAL.csv'.format(CSV_NAME), sep='\t', index=False)

# %%
tyres = df[df['department'].str.contains('Automotivo')]
# sorted(tyres['category'].unique())
len(tyres)
# Out:
# 32

# %%
tyres
# Out:
#       _id.id  ean    brand                                               name  \
# 79    466553  N/A  Pirelli        Pneu Pirelli Phantom Aro 16 - 205/55R16 91W
# 149   266130  N/A      N/A  Som Automotivo Dazz com USB/SD e Rádio FM - DZ...
# 302   221299  N/A   Tornel           Pneu Tornel AT909 Aro 13 - 175/70R13 82S
# 349   267888  N/A      N/A                     DVD Automotivo Dazz 7 DZ-65857
# 379   221319  N/A   Tornel            Pneu Tornel Real Aro 15 - 195/65R15 89V
# 401   466550  N/A  Pirelli          Pneu Pirelli P6000 Aro 14 - 185/60R14 82H
# 436   655554  N/A  Pioneer               Som Automotivo Pioneer - DEH-X8780BT
# 437   203405  N/A      N/A         Capacete Fokker Paint Vermelho - Mixs Maxx
# 469   655551  N/A  Pioneer             DVD Automotivo Pioneer 7 - AVH-X5780TV
# 548   576661  N/A  Pioneer                  Som Automotivo Pioneer DEH-6780BT
# 572   466549  N/A  Pirelli           Pneu Pirelli P400 Aro 14 - 185/65R14 85T
# ...
