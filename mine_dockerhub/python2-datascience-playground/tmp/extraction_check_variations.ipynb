# %%
import csv

import numpy as np
import pandas as pd

FILE = 'files/csvs/walmart.extraction.csv'
SEPARATOR = '\t'

df = pd.read_csv(FILE, SEPARATOR, error_bad_lines=False)
# df = pd.read_csv(FILE, SEPARATOR, error_bad_lines=False, quoting=csv.QUOTE_NONE)


blank_fields_values = {
 '_id.id': 0,
 'ean': '',
 'brand': '',
 'name': '', 
 'product_type': '',
 'price': 0,
 'special_price': 0,
 'department': '',
 'category': '',
 'url': '',
 'available': True,
 'instalments': 0,
 'instalment_value': 0,
 'image_url': '',
 'variation_label' : '',
 'tyre.width': 0,
 'tyre.aspect_ratio': 0,
 'tyre.rim_diameter': 0,
 'tyre.load_index': 0,
 'tyre.speed_rating': ''
}
df = df.fillna(value=blank_fields_values)

# df = df.fillna(value='')

# %%
df.count()
# Out:
# _id.id               682102
# ean                  682102
# brand                682102
# name                 682102
# product_type         682102
# price                682102
# special_price        682102
# department           682102
# category             682102
# url                  682102
# available            682102
# instalments          682102
# instalment_value     682102
# image_url            682102
# variation_label      682102
# tyre.width           682102
# tyre.aspect_ratio    682102
# tyre.rim_diameter    682102
# tyre.load_index      682102
# tyre.speed_rating    682102
# dtype: int64

# %%
df.columns
# Out:
# Index([u'_id.id', u'ean', u'brand', u'name', u'product_type', u'price',
#        u'special_price', u'department', u'category', u'url', u'available',
#        u'instalments', u'instalment_value', u'image_url', u'variation_label',
#        u'tyre.width', u'tyre.aspect_ratio', u'tyre.rim_diameter',
#        u'tyre.load_index', u'tyre.speed_rating'],
#       dtype='object')

# %%
df.tail(5)
# Out:
#          _id.id ean   brand  \
# 682097  3173294      Toyota
# 682098  3173297      Revlon
# 682099  3173291      Revlon
# 682100  3173277       Carlu
# 682101  3173275       Carlu
#
#                                                      name      product_type  \
# 682097         CHAVE CANIVETE TOYOTA BrancaPARA HILUX SW4           Alarmes
# 682098  Sombra Revlon Photoready Primer Shadow Waterco...             Olhos
# 682099  Sombra Revlon Photoready Primer Shadow Muse 50...             Olhos
# 682100                   Memória Formas Geométricas Carlu  Jogos Educativos
# 682101                  Memória Animais Vertebrados Carlu  Jogos Educativos
#
#         price  special_price               department    category  \
# 682097  44.90          44.90               Automotivo  Acessórios
# 682098  79.90          79.90  Perfumaria e Cosméticos   Maquiagem
# 682099  79.90          79.90  Perfumaria e Cosméticos   Maquiagem
# 682100  19.89          19.89               Brinquedos       Jogos
# 682101  14.99          14.99               Brinquedos       Jogos
#
#                                                       url available  \
# 682097  http://www.walmart.com.br/chave-canivete-toyot...     False
# 682098  http://www.walmart.com.br/sombra-revlon-photor...     False
# 682099  http://www.walmart.com.br/sombra-revlon-photor...     False
# 682100  http://www.walmart.com.br/memoria-formas-geome...     False
# 682101  http://www.walmart.com.br/memoria-animais-vert...     False
#
#         instalments  instalment_value  \
# 682097            0              0.00
# 682098            3             26.63
# 682099            3             26.63
# 682100            0              0.00
# 682101            0              0.00
#
#                                                 image_url variation_label  \
# 682097  http://static.wmobjects.com.br/imgres/arquivos...
# 682098  http://static.wmobjects.com.br/imgres/arquivos...
# 682099  http://static.wmobjects.com.br/imgres/arquivos...
# 682100  http://static.wmobjects.com.br/imgres/arquivos...
# 682101  http://static.wmobjects.com.br/imgres/arquivos...
#
#         tyre.width  tyre.aspect_ratio  tyre.rim_diameter  tyre.load_index  \
# 682097           0                  0                  0                0
# 682098         520                 11                 88                0
# 682099         503                 18                 80                0
# 682100           0                  0                  0                0
# 682101           0                  0                  0                0
#
#        tyre.speed_rating
# 682097
# 682098
# 682099
# 682100
# 682101

# %%
df['available'].unique()
# Out:
# array([False], dtype=object)

# %%
variations = df['variation_label'].unique()
sorted(variations)
# Out:
# ['']
